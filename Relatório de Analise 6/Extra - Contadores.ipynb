# %% [markdown]
# # Extra Contadores

# %%
import pandas as pd

# %%
# Outra maneira de remover itens duplicados
# Criando uma Series
s = pd.Series(list('sasasasadsdsesa'))
s
# Out:
# 0     s
# 1     a
# 2     s
# 3     a
# 4     s
# 5     a
# 6     s
# 7     a
# 8     d
# 9     s
# 10    d
# 11    s
# 12    e
# 13    s
# 14    a
# dtype: object

# %%
# O unique retorna os itens unico, sem os duplicados
s.unique()
# Out:
# array(['s', 'a', 'd', 'e'], dtype=object)

# %%
# O value_counts retorna a quantidade de veses que um valor foi duplicado, ou seja sua frequencia
s.value_counts()
# Out:
# s    7
# a    5
# d    2
# e    1
# dtype: int64

# %%
# Importando dados do csv
dados = pd.read_csv('../dados/aluguel_residencial.csv', sep=';')
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# ...

# %%
# O unique retorna os itens unico, sem os duplicados
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio',
#        'Casa de Vila'], dtype=object)

# %%
# O value_counts retorna a quantidade de veses que um valor foi duplicado, ou seja sua frequencia
dados.Tipo.value_counts()
# Out:
# Apartamento           18780
# Casa de Condomínio      996
# Casa                    965
# Quitinete               836
# Casa de Vila            249
# Name: Tipo, dtype: int64

# %% [markdown]
# ## Atividades Alura

# %%
m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
eventos = {'m1': list(m1), 
            'm2': list(m2), 
            'm3': list(m3), 
            'm4': list(m4), 
            'm5': list(m5)}
moedas = pd.DataFrame(eventos)
moedas
# Out:
#    m1 m2 m3 m4 m5
# 0   C  C  C  c  C
# 1   C  C  c  C  C
# 2   c  C  c  C  C
# 3   C  C  C  c  c
# 4   C  C  C  c  C
# 5   c  c  c  C  c
# 6   c  c  c  C  C
# 7   C  C  C  c  c
# 8   C  c  c  c  C
# 9   C  c  C  C  c
# 10  c  C  C  C  C
# 11  c  c  C  c  C
# 12  C  C  C  c  C
# 13  c  C  C  C  c
# 14  C  C  C  C  C
# 15  c  C  C  c  C
# 16  c  c  C  c  c
# 17  C  c  C  c  C
# 18  c  C  C  c  c
# 19  C  c  c  C  C
# 20  c  c  c  c  C
# 21  C  c  c  C  c
# 22  C  c  C  c  c
# 23  C  C  c  C  C
# 24  c  c  c  c  c
# 25  C  c  C  C  C
# 26  C  C  C  c  C
# 27  c  c  C  C  c
# 28  c  c  C  c  c
# 29  c  C  C  C  c
# 30  C  C  C  c  C
# 31  C  c  c  C  c
# 32  c  C  c  C  c
# 33  C  c  C  C  C
# 34  c  c  C  C  C
# 35  C  C  C  c  c
# 36  c  c  c  c  C
# 37  C  C  c  c  c
# 38  c  c  c  c  C
# 39  c  C  C  C  c
# 40  c  C  C  C  C
# 41  C  c  C  C  c
# 42  C  C  c  c  C
# 43  c  c  C  C  c
# 44  C  c  C  C  c
# 45  c  C  c  c  c
# 46  c  c  c  C  c
# 47  c  c  c  C  c
# 48  C  C  C  C  C
# ...

# %%
df = pd.DataFrame(data = ['Cara', 'Coroa'], 
                    index = ['c', 'C'], 
                    columns = ['Faces'])
df
# Out:
#    Faces
# c   Cara
# C  Coroa

# %%
coroasm2 = moedas['m2'][moedas['m2'] == 'C']
coroasm2.shape
# Out:
# (24,)

# %%
carasm2 = moedas['m2'][moedas['m2'] == 'c']
carasm2.shape
# Out:
# (26,)

# %%
for item in moedas:
    df = pd.concat([df, moedas[item].value_counts()], 
                    axis = 1)
df
# Out:
# /home/paulo/.conda/envs/alura_pandas/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Faces  m1  m2  m3  m4  m5
# C  Coroa  25  24  31  27  25
# c   Cara  25  26  19  23  25
